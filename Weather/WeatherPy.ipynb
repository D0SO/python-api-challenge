# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
# citypy allows us to determine cities based on latitude and longitude
from citipy import citipy

# Import wether api zccess key
from api_keys import weather_api_key


# Define range of latitudes and longitudes
lat_rng = (-90,90)
lng_rng  = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Create empty lists to store coordinates and city names
coordinates = []
cities = []

# Create variable to store random set of latitude and longitude values
lat = np.random.uniform(lat_rng[0], lat_rng[1], size = 1500) 
lng = np.random.uniform(lng_rng[0], lng_rng[1], size = 1500)
# Store both sets together
coordinates = zip(lat,lng)

# We create a loop that uses citipy to identify the nearest city to each set of coordinates
for lat_lng in coordinates:
    # Store the city name in a variable using citipy
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # Append the city name to our cities liest
    if city not in cities:
        cities.append(city)
# Print the count of cities 
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Createa variable for the API URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Create a list to store the data of each city
city_data = []

# Create counters
record_count = 1


for city in cities:
    # Create url for each city in our list
    query_url =f"{url}&q={city}"

    # Try and except function help us treat missing data
    try: 
        #Request data and parse it in json
        response = requests.get(query_url).json()
        
        # parse the data into each category
        country = response["sys"]["country"]
        city_name = response["name"]
        date = response["dt"]
        cloudiness = response["clouds"]["all"]
        wind_speed = response["wind"]["speed"]
        humidity = response["main"]["humidity"]
        max_temp = response["main"]["temp_max"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        # Update the record count 
        record_count +=1
        
            # Append data to our data list
        city_data.append({"City": city_name, 
                        "Lat": latitude, 
                        "Lng": longitude, 
                        "Max Temp": max_temp,
                        "Humidity": humidity,
                        "Cloudiness": cloudiness,
                        "Wind Speed": wind_speed,
                        "Country": country,
                        "Date": date})
            # Print the city name and correspendent reccord
        print(f"Processing Record{record_count} | city: {city}")
        
    except Exception:
        print('City not found! skipping...')

print(" --- Data Collection Completed --- ")
# Out:
# sing Record63 | city: butaritari
# Processing Record64 | city: kodiak
# Processing Record65 | city: itoman
# Processing Record66 | city: saint-philippe
# Processing Record67 | city: lesnoye
# Processing Record68 | city: lompoc
# Processing Record69 | city: petropavlovsk-kamchatskiy
# Processing Record70 | city: dikson
# Processing Record71 | city: usinsk
# Processing Record72 | city: zapolyarnyy
# Processing Record73 | city: yellowknife
# Processing Record74 | city: soria
# Processing Record75 | city: tiarei
# Processing Record76 | city: busselton
# Processing Record77 | city: arraial do cabo
# Processing Record78 | city: broome
# Processing Record79 | city: abu samrah
# Processing Record80 | city: longyearbyen
# Processing Record81 | city: mahina
# Processing Record82 | city: puerto del rosario
# Processing Record83 | city: mangrol
# City not found! skipping...
# Processing Record84 | city: paamiut
# City not found! skipping...
# City not found! skipping...
# Processing Record85 | city: ilam
# Processing Record86 | city: jiquipilas
# Processing Record87 | city: baruun-urt
# Processing Record88 | city: jamestown
# Processing Record89 | city: meulaboh
# Processing Record90 | city: flagstaff
# Processing Record91 | city: bichura
# Processing Record92 | city: qaanaaq
# Processing Record93 | city: jaguey grande
# Processing Record94 | city: puerto ayora
# Processing Record95 | city: alta floresta
# Processing Record96 | city: mago
# Processing Record97 | city: cape town
# Processing Record98 | city: calbuco
# Processing Record99 | city: mercedes
# Processing Record100 | city: tasiilaq
# Processing Record101 | city: dwarka
# Processing Record102 | city: harsin
# Processing Record103 | city: manokwari
# Processing Record104 | city: tecoanapa
# Processing Record105 | city: port hedland
# Processing Record106 | city: chapais
# Processing Record107 | city: nikolskoye
# Processing Record108 | city: eureka
# Processing Record109 | city: sterling
# Processing Record110 | city: dingle
# Processing Record111 | city: vaini
# Processing Record112 | city: nara
# Processing Record113 | city: isangel
# City not found! skipping...
# Processing Record114 | city: eufaula
# Processing Record115 | city: balabac
# Processing Record116 | city: bathsheba
# Processing Record117 | city: hobart
# Processing Record118 | city: kavieng
# Processing Record119 | city: lukiv
# Processing Record120 | city: harper
# City not found! skipping...
# Processing Record121 | city: sosnovo-ozerskoye
# Processing Record122 | city: souillac
# Processing Record123 | city: loreto
# City not found! skipping...
# Processing Record124 | city: muli
# Processing Record125 | city: saint george
# Processing Record126 | city: east london
# Processing Record127 | city: alice springs
# Processing Record128 | city: port alfred
# Processing Record129 | city: nouadhibou
# Processing Record130 | city: locri
# Processing Record131 | city: kem
# Processing Record132 | city: garowe
# Processing Record133 | city: lazaro cardenas
# Processing Record134 | city: san luis
# City not found! skipping...
# Processing Record135 | city: pacific grove
# Processing Record136 | city: ostrovnoy
# Processing Record137 | city: udachnyy
# Processing Record138 | city: dalbandin
# Processing Record139 | city: nanortalik
# Processing Record140 | city: tiksi
# Processing Record141 | city: walvis bay
# Processing Record142 | city: clyde river
# Processing Record143 | city: airai
# Processing Record144 | city: luderitz
# Processing Record145 | city: porto novo
# City not found! skipping...
# Processing Record146 | city: ketchikan
# Processing Record147 | city: jinchang
# Processing Record148 | city: wattens
# Processing Record149 | city: santa fe
# Processing Record150 | city: rio grande
# Processing Record151 | city: nome
# Processing Record152 | city: mihijam
# Processing Record153 | city: sur
# Processing Record154 | city: manadhoo
# Processing Record155 | city: kenai
# Processing Record156 | city: kahului
# Processing Record157 | city: yerbogachen
# City not found! skipping...
# Processing Record158 | city: chara
# City not found! skipping...
# Processing Record159 | city: chokurdakh
# Processing Record160 | city: miri
# Processing Record161 | city: ipojuca
# Processing Record162 | city: guerrero negro
# Processing Record163 | city: hithadhoo
# Processing Record164 | city: port augusta
# Processing Record165 | city: bismarck
# Processing Record166 | city: asfi
# Processing Record167 | city: mahebourg
# Processing Record168 | city: roma
# Processing Record169 | city: tanout
# Processing Record170 | city: khatanga
# Processing Record171 | city: henties bay
# Processing Record172 | city: chicama
# Processing Record173 | city: lagoa
# Processing Record174 | city: kruisfontein
# Processing Record175 | city: vardo
# Processing Record176 | city: severo-kurilsk
# City not found! skipping...
# Processing Record177 | city: kizukuri
# Processing Record178 | city: mackay
# Processing Record179 | city: thompson
# Processing Record180 | city: bairiki
# Processing Record181 | city: gedzhukh
# Processing Record182 | city: champua
# Processing Record183 | city: aden
# City not found! skipping...
# Processing Record184 | city: klaksvik
# Processing Record185 | city: freeport
# Processing Record186 | city: chuy
# Processing Record187 | city: hasaki
# Processing Record188 | city: ulaanbaatar
# Processing Record189 | city: santa rosa
# Processing Record190 | city: jizan
# Processing Record191 | city: lavrentiya
# Processing Record192 | city: kavaratti
# Processing Record193 | city: cidreira
# Processing Record194 | city: namatanai
# Processing Record195 | city: iqaluit
# Processing Record196 | city: fort nelson
# Processing Record197 | city: luganville
# Processing Record198 | city: lugovoy
# City not found! skipping...
# Processing Record199 | city: kaniama
# Processing Record200 | city: witu
# Processing Record201 | city: deputatskiy
# Processing Record202 | city: namibe
# Processing Record203 | city: pangnirtung
# Processing Record204 | city: melita
# City not found! skipping...
# Processing Record205 | city: tiznit
# Processing Record206 | city: nova prata
# Processing Record207 | city: gat
# Processing Record208 | city: carutapera
# Processing Record209 | city: kamaishi
# Processing Record210 | city: bela
# Processing Record211 | city: port-cartier
# Processing Record212 | city: jutai
# Processing Record213 | city: sao felix do xingu
# Processing Record214 | city: kyra
# Processing Record215 | city: tuatapere
# Processing Record216 | city: leiyang
# Processing Record217 | city: alberton
# Processing Record218 | city: vila velha
# Processing Record219 | city: castro
# City not found! skipping...
# Processing Record220 | city: kaitangata
# Processing Record221 | city: hay river
# Processing Record222 | city: mandalgovi
# Processing Record223 | city: ahuimanu
# Processing Record224 | city: ribeira grande
# Processing Record225 | city: leningradskiy
# Processing Record226 | city: taltal
# Processing Record227 | city: buchanan
# Processing Record228 | city: arlit
# Processing Record229 | city: provideniya
# Processing Record230 | city: galveston
# Processing Record231 | city: zielona gora
# City not found! skipping...
# City not found! skipping...
# Processing Record232 | city: coquimbo
# Processing Record233 | city: diadema
# Processing Record234 | city: alofi
# Processing Record235 | city: mopipi
# City not found! skipping...
# Processing Record236 | city: kaltasy
# City not found! skipping...
# Processing Record237 | city: betafo
# Processing Record238 | city: san lorenzo
# Processing Record239 | city: minab
# Processing Record240 | city: bilibino
# Processing Record241 | city: almaznyy
# Processing Record242 | city: atar
# City not found! skipping...
# Processing Record243 | city: sena madureira
# Processing Record244 | city: vostok
# Processing Record245 | city: bambous virieux
# Processing Record246 | city: richards bay
# Processing Record247 | city: torbay
# City not found! skipping...
# Processing Record248 | city: belmonte
# Processing Record249 | city: ust-kulom
# Processing Record250 | city: codrington
# Processing Record251 | city: fort-shevchenko
# Processing Record252 | city: lorengau
# Processing Record253 | city: novoorsk
# Processing Record254 | city: mapimi
# Processing Record255 | city: the valley
# Processing Record256 | city: mbini
# Processing Record257 | city: yatou
# Processing Record258 | city: pocone
# Processing Record259 | city: bafoulabe
# City not found! skipping...
# Processing Record260 | city: krasnogorskoye
# Processing Record261 | city: touros
# Processing Record262 | city: nakonde
# Processing Record263 | city: vizinga
# Processing Record264 | city: port hardy
# Processing Record265 | city: constitucion
# Processing Record266 | city: hilo
# Processing Record267 | city: vila
# Processing Record268 | city: novoilinsk
# Processing Record269 | city: arvika
# Processing Record270 | city: seymchan
# Processing Record271 | city: esperance
# Processing Record272 | city: poum
# Processing Record273 | city: shostka
# Processing Record274 | city: ziyang
# Processing Record275 | city: pingliang
# Processing Record276 | city: krasnyy bogatyr
# Processing Record277 | city: puerto palomas
# Processing Record278 | city: altay
# Processing Record279 | city: dongsheng
# Processing Record280 | city: aklavik
# Processing Record281 | city: borogontsy
# Processing Record282 | city: carnarvon
# Processing Record283 | city: riyadh
# Processing Record284 | city: general pico
# Processing Record285 | city: rawson
# Processing Record286 | city: ponta do sol
# Processing Record287 | city: waingapu
# Processing Record288 | city: meadow lake
# Processing Record289 | city: solwezi
# Processing Record290 | city: iquitos
# Processing Record291 | city: waverly
# Processing Record292 | city: hambantota
# Processing Record293 | city: boyuibe
# Processing Record294 | city: iowa city
# Processing Record295 | city: geraldton
# City not found! skipping...
# Processing Record296 | city: lhokseumawe
# Processing Record297 | city: yablochnyy
# Processing Record298 | city: russell
# Processing Record299 | city: saldanha
# Processing Record300 | city: catuday
# Processing Record301 | city: winnemucca
# City not found! skipping...
# Processing Record302 | city: rio rancho
# Processing Record303 | city: guaruja
# Processing Record304 | city: constantine
# Processing Record305 | city: san patricio
# Processing Record306 | city: pontes e lacerda
# Processing Record307 | city: kirakira
# City not found! skipping...
# City not found! skipping...
# Processing Record308 | city: pacifica
# Processing Record309 | city: tazovskiy
# Processing Record310 | city: santa isabel do rio negro
# Processing Record311 | city: springbok
# Processing Record312 | city: ljubinje
# Processing Record313 | city: provost
# Processing Record314 | city: yenagoa
# Processing Record315 | city: crotone
# Processing Record316 | city: sakata
# Processing Record317 | city: mlawa
# Processing Record318 | city: mineiros
# Processing Record319 | city: hanna
# Processing Record320 | city: sayyan
# Processing Record321 | city: pangody
# Processing Record322 | city: tuktoyaktuk
# Processing Record323 | city: shingu
# Processing Record324 | city: spearfish
# Processing Record325 | city: umm lajj
# Processing Record326 | city: bojnurd
# Processing Record327 | city: biak
# Processing Record328 | city: daytona beach
# Processing Record329 | city: khash
# Processing Record330 | city: jesus carranza
# Processing Record331 | city: zykovo
# Processing Record332 | city: plettenberg bay
# Processing Record333 | city: melo
# City not found! skipping...
# Processing Record334 | city: san vicente
# Processing Record335 | city: yumen
# City not found! skipping...
# Processing Record336 | city: harlingen
# Processing Record337 | city: salalah
# Processing Record338 | city: sao gabriel da cachoeira
# Processing Record339 | city: malinovskiy
# Processing Record340 | city: jining
# Processing Record341 | city: arauca
# Processing Record342 | city: bykivka
# Processing Record343 | city: haapiti
# Processing Record344 | city: wagar
# Processing Record345 | city: antoniny
# Processing Record346 | city: anadyr
# Processing Record347 | city: challapata
# Processing Record348 | city: hurghada
# City not found! skipping...
# Processing Record349 | city: san ramon
# Processing Record350 | city: kimbe
# Processing Record351 | city: luanda
# Processing Record352 | city: ahipara
# Processing Record353 | city: shetpe
# Processing Record354 | city: kodoli
# Processing Record355 | city: chimbote
# Processing Record356 | city: mao
# Processing Record357 | city: san felipe
# Processing Record358 | city: lebu
# Processing Record359 | city: beringovskiy
# Processing Record360 | city: barra do garcas
# Processing Record361 | city: marsabit
# Processing Record362 | city: dickinson
# City not found! skipping...
# Processing Record363 | city: doha
# Processing Record364 | city: talnakh
# Processing Record365 | city: guozhen
# Processing Record366 | city: tame
# Processing Record367 | city: la ronge
# City not found! skipping...
# Processing Record368 | city: antofagasta
# Processing Record369 | city: honiara
# Processing Record370 | city: namuac
# Processing Record371 | city: lata
# Processing Record372 | city: astana
# Processing Record373 | city: avanigadda
# Processing Record374 | city: boguchany
# Processing Record375 | city: cabra
# Processing Record376 | city: berlevag
# Processing Record377 | city: kiunga
# City not found! skipping...
# Processing Record378 | city: qasigiannguit
# Processing Record379 | city: prachuap khiri khan
# Processing Record380 | city: velez-malaga
# Processing Record381 | city: mitsamiouli
# Processing Record382 | city: longhua
# Processing Record383 | city: saskylakh
# City not found! skipping...
# Processing Record384 | city: buluang
# Processing Record385 | city: grand gaube
# Processing Record386 | city: kilrush
# Processing Record387 | city: sorland
# Processing Record388 | city: ancud
# Processing Record389 | city: hofn
# Processing Record390 | city: conway
# Processing Record391 | city: pedro ii
# Processing Record392 | city: porbandar
# Processing Record393 | city: huntington beach
# Processing Record394 | city: tokur
# City not found! skipping...
# Processing Record395 | city: amapa
# Processing Record396 | city: inzer
# Processing Record397 | city: havre-saint-pierre
# Processing Record398 | city: bundaberg
# Processing Record399 | city: barranca
# Processing Record400 | city: tobol
# Processing Record401 | city: kota kinabalu
# Processing Record402 | city: narsaq
# Processing Record403 | city: metro
# Processing Record404 | city: aksha
# Processing Record405 | city: mporokoso
# Processing Record406 | city: samarkand
# Processing Record407 | city: tungor
# Processing Record408 | city: fare
# Processing Record409 | city: maniwaki
# Processing Record410 | city: kontagora
# Processing Record411 | city: belaya gora
# Processing Record412 | city: banda aceh
# Processing Record413 | city: san quintin
# Processing Record414 | city: primorsk
# Processing Record415 | city: banjarmasin
# Processing Record416 | city: sibolga
# Processing Record417 | city: oeiras do para
# City not found! skipping...
# Processing Record418 | city: lao cai
# Processing Record419 | city: ternate
# Processing Record420 | city: sioux lookout
# Processing Record421 | city: khetri
# Processing Record422 | city: akcakoca
# City not found! skipping...
# Processing Record423 | city: itarema
# Processing Record424 | city: macultepec
# Processing Record425 | city: deogarh
# Processing Record426 | city: mitu
# Processing Record427 | city: saint-augustin
# Processing Record428 | city: macieira de cambra
# Processing Record429 | city: ban dung
# Processing Record430 | city: hamilton
# City not found! skipping...
# Processing Record431 | city: camana
# Processing Record432 | city: maniitsoq
# Processing Record433 | city: bahir dar
# Processing Record434 | city: coihaique
# Processing Record435 | city: yarada
# Processing Record436 | city: tigil
# Processing Record437 | city: apartado
# Processing Record438 | city: georgiyevka
# Processing Record439 | city: svetlogorsk
# Processing Record440 | city: agadez
# Processing Record441 | city: diffa
# Processing Record442 | city: platonovka
# Processing Record443 | city: gustavo diaz ordaz
# Processing Record444 | city: huancabamba
# City not found! skipping...
# Processing Record445 | city: newry
# Processing Record446 | city: ananas
# Processing Record447 | city: bambanglipuro
# Processing Record448 | city: margate
# Processing Record449 | city: jhargram
# Processing Record450 | city: abbeville
# Processing Record451 | city: ternovka
# Processing Record452 | city: kondinskoye
# Processing Record453 | city: shache
# Processing Record454 | city: naranjal
# Processing Record455 | city: adre
# Processing Record456 | city: inuvik
# Processing Record457 | city: progreso
# Processing Record458 | city: norman wells
# Processing Record459 | city: porto de moz
# Processing Record460 | city: velsk
# Processing Record461 | city: aswan
# Processing Record462 | city: randfontein
# Processing Record463 | city: bonthe
# Processing Record464 | city: alappuzha
# Processing Record465 | city: kununurra
# Processing Record466 | city: salme
# Processing Record467 | city: ponta delgada
# Processing Record468 | city: vieste
# Processing Record469 | city: enid
# Processing Record470 | city: mogadishu
# Processing Record471 | city: catumbela
# City not found! skipping...
# Processing Record472 | city: okhotsk
# Processing Record473 | city: mbalmayo
# Processing Record474 | city: tamandare
# Processing Record475 | city: barbastro
# Processing Record476 | city: ayan
# Processing Record477 | city: kloulklubed
# Processing Record478 | city: taoudenni
# Processing Record479 | city: kibala
# Processing Record480 | city: gwadar
# Processing Record481 | city: strezhevoy
# Processing Record482 | city: northam
# Processing Record483 | city: plouzane
# Processing Record484 | city: sampit
# Processing Record485 | city: hisua
# Processing Record486 | city: damghan
# Processing Record487 | city: fasa
# Processing Record488 | city: orda
# Processing Record489 | city: talcahuano
# Processing Record490 | city: huarmey
# Processing Record491 | city: smithers
# Processing Record492 | city: broken hill
# Processing Record493 | city: mikuni
# City not found! skipping...
# Processing Record494 | city: krumovgrad
# Processing Record495 | city: onalaska
# Processing Record496 | city: peniche
# Processing Record497 | city: eucaliptus
# Processing Record498 | city: divnogorsk
# Processing Record499 | city: tadine
# Processing Record500 | city: vrede
# Processing Record501 | city: vallenar
# Processing Record502 | city: gamba
# City not found! skipping...
# Processing Record503 | city: morgantown
# Processing Record504 | city: chengalpattu
# Processing Record505 | city: udayagiri
# Processing Record506 | city: lander
# Processing Record507 | city: pisco
# Processing Record508 | city: sechura
# Processing Record509 | city: kraskino
# Processing Record510 | city: andros town
# Processing Record511 | city: waimes
# Processing Record512 | city: borgarnes
# Processing Record513 | city: opuwo
# Processing Record514 | city: baoding
# Processing Record515 | city: karatuzskoye
# Processing Record516 | city: betera
# Processing Record517 | city: podgornoye
# Processing Record518 | city: san jeronimo
# Processing Record519 | city: port blair
# Processing Record520 | city: igarka
# Processing Record521 | city: novoblagodarnoye
# Processing Record522 | city: odweyne
# Processing Record523 | city: sarangani
# Processing Record524 | city: bar-le-duc
# City not found! skipping...
# Processing Record525 | city: manvi
# Processing Record526 | city: pudozh
# Processing Record527 | city: tura
# City not found! skipping...
# Processing Record528 | city: basoko
# Processing Record529 | city: kolochava
# Processing Record530 | city: kaeo
# Processing Record531 | city: togur
# Processing Record532 | city: goya
# Processing Record533 | city: coahuayana
# Processing Record534 | city: avera
# Processing Record535 | city: stettler
# Processing Record536 | city: iracoubo
# Processing Record537 | city: camacha
# City not found! skipping...
# Processing Record538 | city: olafsvik
# City not found! skipping...
# Processing Record539 | city: moranbah
# Processing Record540 | city: carhuamayo
# Processing Record541 | city: pokhara
# Processing Record542 | city: inhambane
# Processing Record543 | city: newport
# Processing Record544 | city: liuhe
# Processing Record545 | city: muros
# Processing Record546 | city: isla mujeres
# Processing Record547 | city: aberdeen
# Processing Record548 | city: beyneu
# Processing Record549 | city: mount gambier
# Processing Record550 | city: yaan
# Processing Record551 | city: grindavik
# Processing Record552 | city: shellbrook
#  --- Data Collection Completed ---

# %%
#Transform our city_data list into a pandas data frame
city_df = pd.DataFrame(city_data)
# List the number of entries in each column
city_df.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Save the data frame into csv
city_df.to_csv('../output_data/cities.csv')
city_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Viedma -40.8135  -62.9967     70.32        73          71
# 1          Port Moresby  -9.4431  147.1797     75.20        94          40
# 2                Bassar   9.2500    0.7833     96.80        16           0
# 3               Chuzhou  32.3219  118.2978     46.00        49          26
# 4  Makkah al Mukarramah  21.4267   39.8261     84.38        29           9
#
#    Wind Speed Country        Date
# 0       17.38      AR  1614690579
# 1        5.75      PG  1614690409
# 2       11.50      TG  1614690579
# 3        1.99      CN  1614690579
# 4        8.90      SA  1614690460

# %%
# Show a statistical summary of our data
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  551.000000  551.000000  551.000000  551.000000  551.000000  551.000000
# mean    20.289282   14.990749   53.143884   68.923775   49.254083    8.858857
# std     33.017157   90.341310   31.935512   21.847188   40.710785    6.106042
# min    -54.800000 -175.200000  -41.100000    6.000000    0.000000    0.270000
# 25%     -7.897350  -66.977300   33.095000   59.000000    1.000000    4.350000
# 50%     24.700000   20.040300   62.010000   74.000000   52.000000    7.560000
# 75%     48.405900   88.016700   78.965000   84.500000   90.000000   11.540000
# max     78.218600  179.316700  103.960000  100.000000  100.000000   40.290000
#
#                Date
# count  5.510000e+02
# mean   1.614691e+09
# std    8.781718e+01
# min    1.614690e+09
# 25%    1.614691e+09
# 50%    1.614691e+09
# 75%    1.614691e+09
# max    1.614691e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_data = city_df[(city_df['Humidity'] > 100 )].index
hum_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
low_humidity = city_df.drop(hum_data, inplace = False)
low_humidity.to_csv('../output_data/city_data_clean.csv', index_label = 'CITY_ID') 
low_humidity
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Viedma -40.8135  -62.9967     70.32        73          71
# 1            Port Moresby  -9.4431  147.1797     75.20        94          40
# 2                  Bassar   9.2500    0.7833     96.80        16           0
# 3                 Chuzhou  32.3219  118.2978     46.00        49          26
# 4    Makkah al Mukarramah  21.4267   39.8261     84.38        29           9
# ..                    ...      ...       ...       ...       ...         ...
# 546                Beyneu  45.3167   55.2000     38.97        75         100
# 547         Mount Gambier -37.8333  140.7667     53.60        62          90
# 548                  Yaan   7.3833    8.5667    103.35         8          92
# 549             Grindavik  63.8424  -22.4338     44.60       100          90
# 550            Shellbrook  53.2168 -106.4011     21.20        79          75
#
#      Wind Speed Country        Date
# 0         17.38      AR  1614690579
# 1          5.75      PG  1614690409
# 2         11.50      TG  1614690579
# 3          1.99      CN  1614690579
# 4          8.90      SA  1614690460
# ..          ...     ...         ...
# 546       10.11      KZ  1614690669
# 547        6.91      AU  1614690424
# 548       10.76      NG  1614690670
# 549       11.50      IS  1614690670
# 550       10.36      CA  1614690670
#
# [551 rows x 9 columns]

# %%
# Assign a variable to each of the columns required for plotting
lat = low_humidity["Lat"]
max_temp = low_humidity["Max Temp"]
humidity = low_humidity["Humidity"]
cloudiness = low_humidity["Cloudiness"]
wind_speed = low_humidity["Wind Speed"]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create the scatter plot with the desired variables 
plt.scatter(lat, max_temp, edgecolor = "black", marker= "o", label = "Cities")


# Assign tittle and labels
plt.title("Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving our plot 
plt.savefig("../output_data/plot1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create the scatter plot with the desired variables 
plt.scatter(lat, humidity, edgecolor = "black", marker= "o", label = "Cities")


# Assign tittle and labels
plt.title("«Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Max Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving our plot 
plt.savefig("../output_data/plot2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create the scatter plot with the desired variables 
plt.scatter(lat, cloudiness, edgecolor = "black", marker= "o", label = "Cities")


# Assign tittle and labels
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving our plot 
plt.savefig("../output_data/plot3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create the scatter plot with the desired variables 
plt.scatter(lat, wind_speed, edgecolor = "black", marker= "o", label = "Cities")


# Assign tittle and labels
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving our plot 
plt.savefig("../output_data/plot4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Define our linear regression with y and x vaues to place our data sets, changing title of the graph, and a label with the linear regression equation
def linear_regression(x_values, y_values, y_label, label):
    
    # Call the linear regression function
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create the scatter plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-square is {rvalue}')
    print(line_eq)
    # Print the linear equation
    plt.annotate(line_eq,label,fontsize=15,color="red")
    plt.xlabel('Latitude')
    # Define the y label per corresponding data set
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
north_hem = city_df.loc[(city_df['Lat'] >= 0 )]
south_hem = city_df.loc[(city_df['Lat'] < 0 )]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_values = north_hem['Max Temp']
x_values = north_hem['Lat']
linear_regression(x_values, y_values, 'Max Temp',(0,-10))
# Out:
# The r-square is -0.8592381929953784
# y = -1.46x + 99.95

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_values = south_hem['Max Temp']
x_values = south_hem['Lat']
linear_regression(x_values, y_values, 'Max Temp',(-30,50))
# Out:
# The r-square is 0.45696054173514655
# y = 0.35x + 82.13

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values = north_hem['Humidity']
x_values = north_hem['Lat']
linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-square is 0.39263066026270493
# y = 0.47x + 49.25

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values = south_hem['Humidity']
x_values = south_hem['Lat']
linear_regression(x_values, y_values, 'Humidity',(-55,20))
# Out:
# The r-square is 0.22876516695707103
# y = 0.29x + 78.87

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values = north_hem['Cloudiness']
x_values = north_hem['Lat']
linear_regression(x_values, y_values, 'Cloudiness',(26,5))
# Out:
# The r-square is 0.24115378437608312
# y = 0.5x + 28.53

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values = south_hem['Cloudiness']
x_values = south_hem['Lat']
linear_regression(x_values, y_values, 'Cloudiness',(-55,30))
# Out:
# The r-square is 0.39057987416259515
# y = 1.18x + 77.48

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = north_hem['Wind Speed']
x_values = north_hem['Lat']
linear_regression(x_values, y_values, 'Wind Speed',(10,30))
# Out:
# The r-square is 0.09672203045968114
# y = 0.03x + 8.16

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = south_hem['Wind Speed']
x_values = south_hem['Lat']
linear_regression(x_values, y_values, 'Wind Speed',(-40,0))
# Out:
# The r-square is -0.21535433839078602
# y = -0.08x + 5.94
